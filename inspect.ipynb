# %%
from pathlib import Path
import numpy as np
import pandas as pd
import pydicom
from scipy.ndimage import zoom

path = '/media/jahan/solo/cxr_data/'

files = [] 

for filename in Path(path).glob('**/*.npz'):
    files.append(str(filename))
    
data = np.load(files[0])

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt

plt.imshow(data['a'][1], cmap='gray')
print(np.max(data['a'][1]))
plt.rcParams['figure.figsize'] = [3, 3]
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# 241.0

# %%
plt.imshow(data['b'][1], cmap='gray')

plt.rcParams['figure.figsize'] = [3, 3]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-2c0eee44385f> in <module>
# ----> 1 plt.imshow(data['b'][1], cmap='gray')
#       2
#       3 plt.rcParams['figure.figsize'] = [3, 3]
#       4 plt.show()
#
# ~/miniconda3/envs/cxr/lib/python3.7/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     264                 return self.zip.read(key)
#     265         else:
# --> 266             raise KeyError("%s is not a file in the archive" % key)
#     267
#     268
#
# KeyError: 'b is not a file in the archive'

# %%
from scipy.ndimage import zoom

small = zoom(data['b'][1], 0.25)
print(small.shape)
plt.imshow(small, cmap='gray')

plt.rcParams['figure.figsize'] = [3, 3]
plt.show()
# Out:
# (64, 64)
# <img src="data:image/png;base64,..." width="298.88889680674066">

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from algorithms.autoencoder import convAutoencoder as conv
import tensorflow as tf


test = conv(save_path=save_path, data_path=data_path)
test.build()
