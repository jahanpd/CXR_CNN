# %%
from pathlib import Path
import numpy as np
import pandas as pd
from algorithms.autoencoder import convAutoencoder as conv
import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

save_path = "/home/jahan/Documents/CXR_CNN/output/"
data_path = '/media/jahan/solo/cxr_data/'

resnet = conv(save_path=save_path, data_path=data_path)
resnet.build()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0811 18:23:54.185206 140166245201728 deprecation.py:506] From /home/jahan/miniconda3/envs/cxr/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "ResNetAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 256, 256, 8)  136         input_1[0][0]
# ...

# %%
resnet.train(1)
# Out:
# Epoch 1/10
# 977/977 [==============================] - 18s 19ms/sample - loss: 0.4322
# Epoch 2/10
# 977/977 [==============================] - 9s 9ms/sample - loss: 0.4323
# Epoch 3/10
# 977/977 [==============================] - 9s 9ms/sample - loss: 0.4324
# Epoch 4/10
# 977/977 [==============================] - 8s 9ms/sample - loss: 0.4323
# Epoch 5/10
# 977/977 [==============================] - 8s 8ms/sample - loss: 0.4324
# Epoch 6/10
# 977/977 [==============================] - 8s 9ms/sample - loss: 0.4322
# Epoch 7/10
# 977/977 [==============================] - 9s 10ms/sample - loss: 0.4322
# Epoch 8/10
# 977/977 [==============================] - 9s 9ms/sample - loss: 0.4318
# Epoch 9/10
# 977/977 [==============================] - 9s 9ms/sample - loss: 0.4322
# Epoch 10/10
# 977/977 [==============================] - 9s 9ms/sample - loss: 0.4324
# Epoch 1/10
# 977/977 [==============================] - 9s 9ms/sample - loss: 0.4266
# Epoch 2/10
# ...

# %%
files = [] 

for filename in Path(data_path).glob('**/*.npz'):
    files.append(str(filename))
    
data = np.load(files[0])

# %%
prediction = resnet.autoencoder.predict(data['a'][1].reshape((1,256,256,1)))

# %matplotlib notebook
from matplotlib import pyplot as plt

plt.imshow(prediction.reshape((256,256))*255, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c81a79754291> in <module>
# ----> 1 prediction = resnet.autoencoder.predict(data['a'][1].reshape((1,256,256,1)))
#       2
#       3 get_ipython().run_line_magic('matplotlib', 'notebook')
#       4 from matplotlib import pyplot as plt
#       5
#
# NameError: name 'data' is not defined

# %%
prediction
